# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings

import missingno as msn
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

# %% [markdown]
# ## Importing Dataset

# %%
hf = pd.read_csv("heart failure.csv")
hf
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                      1  265000.00               1.9           130    1
# 1                      0  263358.03               1.1           136    1
# 2                      0  162000.00               1.3           129    1
# 3                      0  210000.00               1.9           137    1
# 4                      0  327000.00               2.7           116    0
# ..                   ...        ...               ...           ...  ...
# 294                    1  155000.00               1.1           143    1
# 295                    0  270000.00               1.2           139    0
# 296                    0  742000.00               0.8           138    0
# 297                    0  140000.00               1.4           140    1
# 298                    0  395000.00               1.6           136    1
#
#      smoking  time  DEATH_EVENT
# 0          0     4            1
# 1          0     6            1
# 2          1     7            1
# 3          0     7            1
# 4          0     8            1
# ..       ...   ...          ...
# 294        1   270            0
# 295        0   271            0
# 296        0   278            0
# 297        1   280            0
# 298        1   285            0
#
# [299 rows x 13 columns]

# %% [markdown]
# ## Standardizing Column Names

# %%
hf.rename(columns={"age":"Age","anaemia":"Anaemia","creatinine_phosphokinase":"Creatinine Phosphokinase","diabetes":"Diabetes",
                  "ejection_fraction":"Ejection Fraction","high_blood_pressure":"HBP","platelets":"Platelets",
                  "serum_creatinine":"Serum Creatinine","serum_sodium":"Serum Sodium","sex":"Sex","smoking":"Smoking",
                  "time":"Time","DEATH_EVENT":"Death Event"},inplace=True)

# %%
hf.head()
# Out:
#     Age  Anaemia  Creatinine Phosphokinase  Diabetes  Ejection Fraction  HBP  \
# 0  75.0        0                       582         0                 20    1
# 1  55.0        0                      7861         0                 38    0
# 2  65.0        0                       146         0                 20    0
# 3  50.0        1                       111         0                 20    0
# 4  65.0        1                       160         1                 20    0
#
#    Platelets  Serum Creatinine  Serum Sodium  Sex  Smoking  Time  Death Event
# 0  265000.00               1.9           130    1        0     4            1
# 1  263358.03               1.1           136    1        0     6            1
# 2  162000.00               1.3           129    1        1     7            1
# 3  210000.00               1.9           137    1        0     7            1
# 4  327000.00               2.7           116    0        0     8            1

# %% [markdown]
# ## *Domain Features*
#
# Categorical - 6
#
# Numerical - 7

# %% [markdown]
# > **Anaemia** - Anaemia refers to a haemoglobin concentration or number of red blood cells below a specified cut-off point.
#                 This cut off point is influenced by factors such as age, gender or even geological locations.
#                 Haemoglobin is an important protein contained in red blood cells that function to transport oxygen to organs.
#
# *Haemoglobin Normal Range - 13.2 to 16.6 grams (g) of hemoglobin per deciliter (dL) of blood for men and 11.6 to 15 g/dL for women* (Boolean)
#
# > **Creatinine Phosphokinase** - Creatine phosphokinase (CPK) is an enzyme in the body. It is found mainly in the heart, brain,
#                                  and skeletal muscle.
#
# *CPK Normal Values: 39 – 308 mcg/L (Male), 26 – 192 mcg/L (Female)* (Boolean)
#
# > **Diabetes** - Diabetes is a chronic disease that occurs either when the pancreas does not produce enough insulin or when the
#                  body cannot effectively use the insulin it produces.
#
# *Blood Sugar Normal Range: After 8 hrs of fasting (70 - 100 mg/dL), After 2 hrs of eating (90 - 100 mg/dL)* (Boolean)
#
# > **Ejection Fraction** - Ejection fraction refers to how well your heart pumps blood. It is the amount of blood pumped out of
#                           your heart’s lower chambers (ventricles) each time it contracts.
#
# *Ejection Fraction Normal Range: Male (52% to 72%), Female (54% to 74%)* (%)
#
# > **HBP** - High blood pressure (also referred to as HBP, or hypertension) is when your blood pressure, the force of blood
#             flowing through your blood vessels, is consistently too high.
#
#
# *Reading: 130/80 mm Hg and above* (Boolean)
#
# > **Platelets** - Platelets are tiny blood cells that help your body form clots to stop bleeding. If one of your blood vessels
#                   gets damaged, it sends out signals to the platelets. The platelets then rush to the site of damage and form a
#                   plug (clot) to fix the damage.
#
# *Platelets Normal Range: 150,000 to 450,000 kiloplatelets/mL*
#
# > **Serum Creatinine** - Creatinine is a waste product in your blood that comes from your muscles. Healthy kidneys filter
#                          creatinine out of your blood through your urine.
#
# *Serum Creatinine Normal Range:     0.7 - 1.3 mg/dL (males), 0.6 - 1.1 mg/dL (females)*
#
# > **Serum Sodium** - Sodium is particularly important for nerve and muscle function.
#                      Too much sodium can raise your blood pressure.
#
# *Serum Sodium Normal Range: 135-147 mEq/L*
#
# > **Sex** - Binary
#
# > **Smoking** - Boolean
#
# > **Time** - Follow up period (Days)
#
# > **DEATH EVENT** - If the patient deceased during the follow-up period (Boolean)

# %%
hf.head()
# Out:
#     Age  Anaemia  Creatinine Phosphokinase  Diabetes  Ejection Fraction  HBP  \
# 0  75.0        0                       582         0                 20    1
# 1  55.0        0                      7861         0                 38    0
# 2  65.0        0                       146         0                 20    0
# 3  50.0        1                       111         0                 20    0
# 4  65.0        1                       160         1                 20    0
#
#    Platelets  Serum Creatinine  Serum Sodium  Sex  Smoking  Time  Death Event
# 0  265000.00               1.9           130    1        0     4            1
# 1  263358.03               1.1           136    1        0     6            1
# 2  162000.00               1.3           129    1        1     7            1
# 3  210000.00               1.9           137    1        0     7            1
# 4  327000.00               2.7           116    0        0     8            1

# %%
# hf["Age"] = pd.cut(x=hf['Age'], bins=[40, 55, 75, 95])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16768\1559038857.py in <module>
# ----> 1 hf["Age"] = pd.cut(x=hf['Age'], bins=[40, 55, 75, 95])
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates, ordered)
#     290             raise ValueError("bins must increase monotonically.")
#     291
# --> 292     fac, bins = _bins_to_cuts(
#     293         x,
#     294         bins,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\tile.py in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates, ordered)
#     425
#     426     side: Literal["left", "right"] = "left" if right else "right"
# --> 427     ids = ensure_platform_int(bins.searchsorted(x, side=side))
#     428
#     429     if include_lowest:
#
# TypeError: '<' not supported between instances of 'int' and 'pandas._libs.interval.Interval'

# %%
hf.tail()
# Out:
#           Age  Anaemia  Creatinine Phosphokinase  Diabetes  Ejection Fraction  \
# 294  (55, 75]        0                        61         1                 38
# 295  (40, 55]        0                      1820         0                 38
# 296  (40, 55]        0                      2060         1                 60
# 297  (40, 55]        0                      2413         0                 38
# 298  (40, 55]        0                       196         0                 45
#
#      HBP  Platelets  Serum Creatinine  Serum Sodium  Sex  Smoking  Time  \
# 294    1   155000.0               1.1           143    1        1   270
# 295    0   270000.0               1.2           139    0        0   271
# 296    0   742000.0               0.8           138    0        0   278
# 297    0   140000.0               1.4           140    1        1   280
# 298    0   395000.0               1.6           136    1        1   285
#
#      Death Event
# 294            0
# 295            0
# 296            0
# 297            0
# 298            0

# %%
hf
# Out:
#           Age  Anaemia  Creatinine Phosphokinase  Diabetes  Ejection Fraction  \
# 0    (55, 75]        0                    582.00         0               20.0
# 1    (40, 55]        0                   1280.25         0               38.0
# 2    (55, 75]        0                    146.00         0               20.0
# 3    (40, 55]        1                    111.00         0               20.0
# 4    (55, 75]        1                    160.00         1               20.0
# ..        ...      ...                       ...       ...                ...
# 294  (55, 75]        0                     61.00         1               38.0
# 295  (40, 55]        0                   1280.25         0               38.0
# 296  (40, 55]        0                   1280.25         1               60.0
# 297  (40, 55]        0                   1280.25         0               38.0
# 298  (40, 55]        0                    196.00         0               45.0
#
#      HBP  Platelets  Serum Creatinine  Serum Sodium  Sex  Smoking  Time  \
# 0      1  265000.00              1.90         130.0    1        0     4
# 1      0  263358.03              1.10         136.0    1        0     6
# 2      0  162000.00              1.30         129.0    1        1     7
# 3      0  210000.00              1.90         137.0    1        0     7
# 4      0  327000.00              2.15         125.0    0        0     8
# ..   ...        ...               ...           ...  ...      ...   ...
# 294    1  155000.00              1.10         143.0    1        1   270
# 295    0  270000.00              1.20         139.0    0        0   271
# 296    0  440000.00              0.80         138.0    0        0   278
# 297    0  140000.00              1.40         140.0    1        1   280
# 298    0  395000.00              1.60         136.0    1        1   285
#
#      Death Event
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# ..           ...
# 294            0
# 295            0
# 296            0
# 297            0
# 298            0
#
# [299 rows x 13 columns]

# %% [markdown]
# ## *Features*

# %% [markdown]
#     P - Perfect
#     U - Unit Change
#
# 1. Age **(Years)**
# 2. Anaemia - 1/0 **(g/dL)**
# 3. Creatinine Phosphokinase - P **(mcg/L)**
# 4. Diabetes - 1/0 **(mg/dL)**
# 5. Ejection Fraction - P **(%)**
# 6. HBP - 1/0 **(mm Hg)**
# 7. Platelets - P **(kiloplatelets/mL)**
# 8. Serum Creatinine - P **(mg/dL)**
# 9. Serum Sodium - P **(mmol/L)**
# 10. Sex - 1/0
# 11. Smoking - 1/0
# 12. Time - P
# 13. Death Event - 1

# %%
hf.shape
# Out:
# (299, 13)

# %%
hf.head()
# Out:
#         Age  Anaemia  Creatinine Phosphokinase  Diabetes  Ejection Fraction  \
# 0  (55, 75]        0                       582         0                 20
# 1  (40, 55]        0                      7861         0                 38
# 2  (55, 75]        0                       146         0                 20
# 3  (40, 55]        1                       111         0                 20
# 4  (55, 75]        1                       160         1                 20
#
#    HBP  Platelets  Serum Creatinine  Serum Sodium  Sex  Smoking  Time  \
# 0    1  265000.00               1.9           130    1        0     4
# 1    0  263358.03               1.1           136    1        0     6
# 2    0  162000.00               1.3           129    1        1     7
# 3    0  210000.00               1.9           137    1        0     7
# 4    0  327000.00               2.7           116    0        0     8
#
#    Death Event
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1

# %%
hf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       292 non-null    category
#  1   Anaemia                   299 non-null    int64
#  2   Creatinine Phosphokinase  299 non-null    int64
#  3   Diabetes                  299 non-null    int64
#  4   Ejection Fraction         299 non-null    int64
#  5   HBP                       299 non-null    int64
#  6   Platelets                 299 non-null    float64
#  7   Serum Creatinine          299 non-null    float64
#  8   Serum Sodium              299 non-null    int64
#  9   Sex                       299 non-null    int64
#  10  Smoking                   299 non-null    int64
#  11  Time                      299 non-null    int64
#  12  Death Event               299 non-null    int64
# dtypes: category(1), float64(2), int64(10)
# memory usage: 28.6 KB

# %% [markdown]
# Datatypes are correctly assigned for each features so there arises no issues whatsoever

# %%
hf.describe()
# Out:
#           Anaemia  Creatinine Phosphokinase    Diabetes  Ejection Fraction  \
# count  299.000000                299.000000  299.000000         299.000000
# mean     0.431438                581.839465    0.418060          38.083612
# std      0.496107                970.287881    0.494067          11.834841
# min      0.000000                 23.000000    0.000000          14.000000
# 25%      0.000000                116.500000    0.000000          30.000000
# 50%      0.000000                250.000000    0.000000          38.000000
# 75%      1.000000                582.000000    1.000000          45.000000
# max      1.000000               7861.000000    1.000000          80.000000
#
#               HBP      Platelets  Serum Creatinine  Serum Sodium         Sex  \
# count  299.000000     299.000000         299.00000    299.000000  299.000000
# mean     0.351171  263358.029264           1.39388    136.625418    0.648829
# std      0.478136   97804.236869           1.03451      4.412477    0.478136
# min      0.000000   25100.000000           0.50000    113.000000    0.000000
# 25%      0.000000  212500.000000           0.90000    134.000000    0.000000
# 50%      0.000000  262000.000000           1.10000    137.000000    1.000000
# 75%      1.000000  303500.000000           1.40000    140.000000    1.000000
# max      1.000000  850000.000000           9.40000    148.000000    1.000000
#
#          Smoking        Time  Death Event
# count  299.00000  299.000000    299.00000
# mean     0.32107  130.260870      0.32107
# std      0.46767   77.614208      0.46767
# min      0.00000    4.000000      0.00000
# 25%      0.00000   73.000000      0.00000
# 50%      0.00000  115.000000      0.00000
# 75%      1.00000  203.000000      1.00000
# max      1.00000  285.000000      1.00000

# %% [markdown]
# **AGE**
#
# 1. Patients diagnosed has ages between 40 - 95
# 2. Average age of the patients is around 61
#
# **CPK**
#
# 1. Most of the patients has CPK levels around 581 which is much higher than the normal range.
# 2. Min creatinine level - 23
# 3. Max creatinine level - 7861
#
# **Ejection Fraction**
#
# 1. Average percentage level < the normal level (38%)
# 2. Min EF - 14%
# 3. Max EF - 80%
#
# **Platelets**
#
# 1. Average platelet count of patients is around 2,63,000.
# 2. Min PC - 25100
# 3. Max PC - 8,50,000 which is much > the normal (1.5 to 4.5)
#
# **Serum Creatinine**
#
# 1. Average level - 1.4
# 2. Min SC - 0.5
# 3. Max SC - 9.4
#
# **Serum Sodium**
#
# 1. Average level - 136
# 2. Min SS - 113
# 3. Max SS - 148
#
# *Skewness present in Creatinine Phosphokinase and Serum Creatine

# %%
hf.corr()
# Out:
#                            Anaemia  Creatinine Phosphokinase  Diabetes  \
# Anaemia                   1.000000                 -0.190741 -0.012729
# Creatinine Phosphokinase -0.190741                  1.000000 -0.009639
# Diabetes                 -0.012729                 -0.009639  1.000000
# Ejection Fraction         0.031557                 -0.044080 -0.004850
# HBP                       0.038182                 -0.070590 -0.012732
# Platelets                -0.043786                  0.024463  0.092193
# Serum Creatinine          0.052174                 -0.016408 -0.046975
# Serum Sodium              0.041882                  0.059550 -0.089551
# Sex                      -0.094769                  0.079791 -0.157730
# Smoking                  -0.107290                  0.002421 -0.147173
# Time                     -0.141414                 -0.009346  0.033726
# Death Event               0.066270                  0.062728 -0.001943
#
#                           Ejection Fraction       HBP  Platelets  \
# Anaemia                            0.031557  0.038182  -0.043786
# Creatinine Phosphokinase          -0.044080 -0.070590   0.024463
# Diabetes                          -0.004850 -0.012732   0.092193
# Ejection Fraction                  1.000000  0.024445   0.072177
# HBP                                0.024445  1.000000   0.049963
# Platelets                          0.072177  0.049963   1.000000
# Serum Creatinine                  -0.011302 -0.004935  -0.041198
# Serum Sodium                       0.175902  0.037109   0.062125
# Sex                               -0.148386 -0.104615  -0.125120
# Smoking                           -0.067315 -0.055711   0.028234
# Time                               0.041729 -0.196439   0.010514
# Death Event                       -0.268603  0.079351  -0.049139
#
#                           Serum Creatinine  Serum Sodium       Sex   Smoking  \
# Anaemia                           0.052174      0.041882 -0.094769 -0.107290
# Creatinine Phosphokinase         -0.016408      0.059550  0.079791  0.002421
# Diabetes                         -0.046975     -0.089551 -0.157730 -0.147173
# Ejection Fraction                -0.011302      0.175902 -0.148386 -0.067315
# HBP                              -0.004935      0.037109 -0.104615 -0.055711
# Platelets                        -0.041198      0.062125 -0.125120  0.028234
# Serum Creatinine                  1.000000     -0.189095  0.006970 -0.027414
# Serum Sodium                     -0.189095      1.000000 -0.027566  0.004813
# Sex                               0.006970     -0.027566  1.000000  0.445892
# Smoking                          -0.027414      0.004813  0.445892  1.000000
# Time                             -0.149315      0.087640 -0.015608 -0.022839
# Death Event                       0.294278     -0.195204 -0.004316 -0.012623
#
#                               Time  Death Event
# Anaemia                  -0.141414     0.066270
# Creatinine Phosphokinase -0.009346     0.062728
# Diabetes                  0.033726    -0.001943
# Ejection Fraction         0.041729    -0.268603
# HBP                      -0.196439     0.079351
# Platelets                 0.010514    -0.049139
# Serum Creatinine         -0.149315     0.294278
# Serum Sodium              0.087640    -0.195204
# Sex                      -0.015608    -0.004316
# Smoking                  -0.022839    -0.012623
# Time                      1.000000    -0.526964
# Death Event              -0.526964     1.000000

# %%
hf["Sex"].value_counts()
# Out:
# 1    194
# 0    105
# Name: Sex, dtype: int64

# %%
plt.figure(figsize=(15,9))
sns.heatmap(hf.corr(),annot=True,cmap="BuPu");

# %% [markdown]
# ## Preprocessing

# %%
# Missing Values
msn.matrix(hf);

# %%
# Duplications
hf.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Outlier Check

# %%
cols = ["Creatinine Phosphokinase", "Ejection Fraction", "Platelets", "Serum Creatinine", "Serum Sodium"]
for col in cols:
    plt.figure(figsize=(6,3))
    sns.boxplot(x = hf[col], color = "brown")
    plt.title(col)

# %% [markdown]
# > Creatinine Phosphokinase, Ejection Fraction, Platelets, Serum Creatine and Serum Sodium contains Outliers

# %% [markdown]
# ### Removing Outliers

# %%
def fences(hf, col):
    Q3 = hf[col].quantile(0.75)
    Q1 = hf[col].quantile(0.25)
    IQR = Q3 - Q1
    UF = Q3 + 1.5*IQR
    LF = Q1 - 1.5*IQR
    return UF, LF

# %%
for col in ["Creatinine Phosphokinase","Ejection Fraction","Serum Creatinine","Platelets","Serum Sodium"]:
    UF, LF = fences(hf, col)
    hf[col] = np.where((hf[col] > UF), UF, hf[col])
    hf[col] = np.where((hf[col] < LF), LF, hf[col])

# %% [markdown]
# ### After Removal

# %%
# Checking for outliers after removal
cols = ["Creatinine Phosphokinase", "Ejection Fraction", "Platelets","Serum Creatinine","Serum Sodium"]
for col in cols:
    plt.figure(figsize=(6,3))
    sns.boxplot(x = hf[col], color = "grey")
    plt.title(col)

# %% [markdown]
# ## Visualizations

# %%
warnings.filterwarnings("ignore")

# %%
hf.head()
# Out:
#         Age  Anaemia  Creatinine Phosphokinase  Diabetes  Ejection Fraction  \
# 0  (55, 75]        0                    582.00         0               20.0
# 1  (40, 55]        0                   1280.25         0               38.0
# 2  (55, 75]        0                    146.00         0               20.0
# 3  (40, 55]        1                    111.00         0               20.0
# 4  (55, 75]        1                    160.00         1               20.0
#
#    HBP  Platelets  Serum Creatinine  Serum Sodium  Sex  Smoking  Time  \
# 0    1  265000.00              1.90         130.0    1        0     4
# 1    0  263358.03              1.10         136.0    1        0     6
# 2    0  162000.00              1.30         129.0    1        1     7
# 3    0  210000.00              1.90         137.0    1        0     7
# 4    0  327000.00              2.15         125.0    0        0     8
#
#    Death Event
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1

# %%
cols = ["Age","Creatinine Phosphokinase", "Platelets", "Serum Creatinine", "Serum Sodium"]
for col in cols:
    plt.figure(figsize=(5,4))
    sns.distplot(x = hf[col], color = "green")
    plt.title(col)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16768\3218335358.py in <module>
#       2 for col in cols:
#       3     plt.figure(figsize=(5,4))
# ----> 4     sns.distplot(x = hf[col], color = "green")
#       5     plt.title(col)
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2634
#    2635     # Make a a 1-d float array
# -> 2636     a = np.asarray(a, float)
#    2637     if a.ndim > 1:
#    2638         a = a.squeeze()
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __array__(self, dtype)
#     870               dtype='datetime64[ns]')
#     871         """
# --> 872         return np.asarray(self._values, dtype)
#     873
#     874     # ----------------------------------------------------------------------
#
# ~\anaconda3\lib\site-packages\pandas\core\arrays\_mixins.py in method(self, *args, **kwargs)
#      82     def method(self, *args, **kwargs):
#      83         if self.ndim == 1:
# ---> 84             return meth(self, *args, **kwargs)
#      85
#      86         flags = self._ndarray.flags
#
# ~\anaconda3\lib\site-packages\pandas\core\arrays\categorical.py in __array__(self, dtype)
#    1504         ret = take_nd(self.categories._values, self._codes)
#    1505         if dtype and not is_dtype_equal(dtype, self.categories.dtype):
# -> 1506             return np.asarray(ret, dtype)
#    1507         # When we're a Categorical[ExtensionArray], like Interval,
#    1508         # we need to ensure __array__ gets all the way to an
#
# TypeError: float() argument must be a string or a number, not 'pandas._libs.interval.Interval'

# %%
def hist(col_name):
    plt.figure(figsize=(5,3))
    sns.histplot(x=hf[col_name],color="navy",kde=True)
    title="{}".format(col_name)
    plt.title(title)

# %% [markdown]
# * Minimum Age is 40 Years
# * Maximum Age is 95 Years
# * Most of the patients are around 60 Years Old

# %%
plt.figure(figsize=(6,4))
sns.histplot(x="Ejection Fraction",hue="Death Event",data=hf);

# %% [markdown]
# * From the graph it is evident that at lower ejection fraction more patients die

# %%
plt.figure(figsize=(6,4))
sns.histplot(x="Serum Creatinine",hue="Death Event",data=hf);

# %% [markdown]
# * Serum Creatinine range above 1.75 affected the patient's health

# %%
cols = ["Sex", "Anaemia", "HBP", "Smoking", "Death Event"]
for col in cols:
    plt.figure(figsize=(5,4))
    sns.countplot(x = hf[col], color = "grey")
    plt.title(col)

# %% [markdown]
# > 194 Males and 105 Females
#
# > Out of the 299 records around 125 were Anaemic
#
# > 105 were diagnosed with hypertension
#
# > Around 99 patients were Smokers
#
# > 203 Patients Survived and 96 died due to heart failure

# %% [markdown]
# # Modeling

# %%
x = hf.drop(columns="Death Event") 
y = hf["Death Event"] 
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=0.2,random_state=1)

# %%
# Feature Scaling using Standard Scaler()
scaler = StandardScaler()
scaler.fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16768\3088396336.py in <module>
#       1 # Feature Scaling using Standard Scaler()
#       2 scaler = StandardScaler()
# ----> 3 scaler.fit(x_train)
#       4 x_train = scaler.transform(x_train)
#       5 x_test = scaler.transform(x_test)
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y, sample_weight)
#     804         # Reset internal state before fitting
#     805         self._reset()
# --> 806         return self.partial_fit(X, y, sample_weight)
#     807
#     808     def partial_fit(self, X, y=None, sample_weight=None):
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in partial_fit(self, X, y, sample_weight)
#     839         """
#     840         first_call = not hasattr(self, "n_samples_seen_")
# --> 841         X = self._validate_data(
#     842             X,
#     843             accept_sparse=("csr", "csc"),
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     564             raise ValueError("Validation should be done on X, y or both.")
#     565         elif not no_val_X and no_val_y:
# --> 566             X = check_array(X, **check_params)
#     567             out = X
#     568         elif no_val_X and not no_val_y:
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     744                     array = array.astype(dtype, casting="unsafe", copy=False)
#     745                 else:
# --> 746                     array = np.asarray(array, order=order, dtype=dtype)
#     747             except ComplexWarning as complex_warning:
#     748                 raise ValueError(
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __array__(self, dtype)
#    2062
#    2063     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2064         return np.asarray(self._values, dtype=dtype)
#    2065
#    2066     def __array_wrap__(
#
# TypeError: float() argument must be a string or a number, not 'pandas._libs.interval.Interval'

# %% [markdown]
# ### Logistic Regression

# %%
lg = LogisticRegression(random_state=1)
lg.fit(x_train, y_train)

y_pred = lg.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: ",accuracy)
print(classification_report(y_test, y_pred))

cmat = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(5,3))
plt.title("Confusion Matrix")
sns.heatmap(cmat,annot=True,cmap="Greens");
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16768\3182991393.py in <module>
#       1 lg = LogisticRegression(random_state=1)
# ----> 2 lg.fit(x_train, y_train)
#       3
#       4 y_pred = lg.predict(x_test)
#       5
#
# NameError: name 'x_train' is not defined

# %% [markdown]
# ### Decision Tree

# %%
dtc = DecisionTreeClassifier(criterion = 'entropy', random_state=1)
dtc.fit(x_train, y_train)

y_pred = dtc.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: ",accuracy)
print(classification_report(y_test, y_pred))

cmat = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(5,3))
plt.title("Confusion Matrix")
sns.heatmap(cmat,annot=True,cmap="Greens");

# %% [markdown]
# ### Random Forest

# %%
rfc = RandomForestClassifier(random_state=1)
rfc.fit(x_train, y_train)

y_pred = rfc.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: ",accuracy)
print(classification_report(y_test, y_pred))

cmat = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(5,3))
plt.title("Confusion Matrix")
sns.heatmap(cmat,annot=True,cmap="Greens");

# %% [markdown]
# ### Naive Bayesian

# %%
nb = GaussianNB()
nb.fit(x_train, y_train)

y_pred = nb.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: ",accuracy)
print(classification_report(y_test, y_pred))

cmat = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(5,3))
plt.title("Confusion Matrix")
sns.heatmap(cmat,annot=True,cmap="Greens");

# %% [markdown]
# ## Support Vector Machine

# %%
svm = SVC(kernel = 'rbf', random_state=1)
svm.fit(x_train, y_train)

y_pred = svm.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: ",accuracy)
print(classification_report(y_test, y_pred))

cmat = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(5,3))
plt.title("Confusion Matrix")
sns.heatmap(cmat,annot=True,cmap="Greens");

# %% [markdown]
# ## Conclusion

# %% [markdown]
# > After analyzing all the parameters Logistic Regression performed at it's maximum with an accuracy of 91.6%.
#
# > Logistic Regression performs best for binary classification problems so it is no surprise that it has peaked the accuracy scale
